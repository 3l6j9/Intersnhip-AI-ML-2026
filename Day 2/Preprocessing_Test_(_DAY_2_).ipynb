# %% [markdown]
# <a href="https://colab.research.google.com/github/3l6j9/Intersnhip-AI-ML-2026/blob/main/Preprocessing_Test_(_DAY_2_).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder
from sklearn.preprocessing import MinMaxScaler
from sklearn.preprocessing import StandardScaler

# %%
df = pd.read_csv("/content/preprocessing_practice_dataset.csv")

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         100 non-null    int64
#  1   Age                 90 non-null     float64
#  2   Gender              100 non-null    object
#  3   Department          90 non-null     object
#  4   Education           90 non-null     object
#  5   Experience_Years    100 non-null    int64
#  6   Monthly_Salary      90 non-null     float64
#  7   Performance_Rating  100 non-null    int64
#  8   City                90 non-null     object
#  9   Attrition           100 non-null    object
# dtypes: float64(2), int64(3), object(5)
# memory usage: 7.9+ KB

# %%
df.isnull().count()
# Out:
# Employee_ID           100
# Age                   100
# Gender                100
# Department            100
# Education             100
# Experience_Years      100
# Monthly_Salary        100
# Performance_Rating    100
# City                  100
# Attrition             100
# dtype: int64

# %%
df.isnull()
# Out:
#     Employee_ID    Age  Gender  Department  Education  Experience_Years  \
# 0         False  False   False       False      False             False
# 1         False  False   False       False      False             False
# 2         False  False   False       False       True             False
# 3         False  False   False       False      False             False
# 4         False  False   False       False      False             False
# ..          ...    ...     ...         ...        ...               ...
# 95        False  False   False       False      False             False
# 96        False  False   False       False      False             False
# 97        False  False   False        True      False             False
# 98        False  False   False       False      False             False
# 99        False  False   False        True       True             False
#
#     Monthly_Salary  Performance_Rating   City  Attrition  Age_mean_imputed
# 0            False               False  False      False             False
# 1            False               False  False      False             False
# 2            False               False  False      False             False
# 3            False               False  False      False             False
# 4            False               False  False      False             False
# ..             ...                 ...    ...        ...               ...
# 95           False               False  False      False             False
# 96           False               False  False      False             False
# 97           False               False  False      False             False
# 98           False               False  False      False             False
# 99           False               False  False      False             False
#
# [100 rows x 11 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   Employee_ID         100 non-null    int64
#  1   Age                 90 non-null     float64
#  2   Gender              100 non-null    object
#  3   Department          90 non-null     object
#  4   Education           90 non-null     object
#  5   Experience_Years    100 non-null    int64
#  6   Monthly_Salary      90 non-null     float64
#  7   Performance_Rating  100 non-null    int64
#  8   City                90 non-null     object
#  9   Attrition           100 non-null    object
#  10  Age_mean_imputed    100 non-null    float64
# dtypes: float64(3), int64(3), object(5)
# memory usage: 8.7+ KB

# %%
sns.set(style = 'darkgrid')

# %%
df['Age_mean_imputed'] = df['Age'].fillna(df['Age'].mean())
df['Department_mode_imputed'] = df['Department'].fillna(df['Department'].mode()[0])
df['Education_mode_imputed'] = df['Education'].fillna(df['Education'].mode()[0])
df['Salary_mean_imputed'] = df['Monthly_Salary'].fillna(df['Monthly_Salary'].mean())
df['City_mode_imputed'] = df['City'].fillna(df['City'].mode()[0])

# %%
df
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition  \
# 0          52350.0                   5     Calicut        No
# 1         118008.0                   2     Chennai       Yes
# 2         119297.0                   1       Kochi       Yes
# 3          50351.0                   2  Trivandrum       Yes
# 4         113668.0                   3  Trivandrum       Yes
# ..             ...                 ...         ...       ...
# 95         48625.0                   5     Chennai       Yes
# 96        107873.0                   5  Trivandrum       Yes
# 97         97592.0                   3     Chennai        No
# 98        102052.0                   5     Calicut       Yes
# 99         69261.0                   2     Calicut        No
#
#     Age_mean_imputed Department_mode_imputed Education_mode_imputed  \
# 0               59.0                      HR                Masters
# 1               49.0               Marketing              Bachelors
# 2               35.0                      HR                Masters
# 3               28.0                      HR                    PhD
# 4               41.0                      IT              Bachelors
# ..               ...                     ...                    ...
# 95              54.0                      HR                Masters
# 96              53.0               Marketing                Masters
# 97              43.0                      HR                    PhD
# 98              44.0               Marketing                    PhD
# 99              57.0                      HR                Masters
#
#     Salary_mean_imputed City_mode_imputed
# 0               52350.0           Calicut
# 1              118008.0           Chennai
# 2              119297.0             Kochi
# 3               50351.0        Trivandrum
# 4              113668.0        Trivandrum
# ..                  ...               ...
# 95              48625.0           Chennai
# 96             107873.0        Trivandrum
# 97              97592.0           Chennai
# 98             102052.0           Calicut
# 99              69261.0           Calicut
#
# [100 rows x 15 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee_ID              100 non-null    int64
#  1   Age                      90 non-null     float64
#  2   Gender                   100 non-null    object
#  3   Department               90 non-null     object
#  4   Education                90 non-null     object
#  5   Experience_Years         100 non-null    int64
#  6   Monthly_Salary           90 non-null     float64
#  7   Performance_Rating       100 non-null    int64
#  8   City                     90 non-null     object
#  9   Attrition                100 non-null    object
#  10  Age_mean_imputed         100 non-null    float64
#  11  Department_mode_imputed  100 non-null    object
#  12  Education_mode_imputed   100 non-null    object
#  13  Salary_mean_imputed      100 non-null    float64
#  14  City_mode_imputed        100 non-null    object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 11.8+ KB

# %%
plt.hist(df['Experience_Years'].dropna(), bins=10)
plt.title('Experience Distribution')
plt.xlabel('Experience')
plt.ylabel('Frequency')
plt.show()

# %%
sns.histplot(df['Experience_Years'], bins=10, kde=True)
plt.show()

sns.histplot(df['Monthly_Salary'], bins=10, kde=True)
plt.show()

# %%
sns.boxplot(x=df['Experience_Years'])
plt.show()

sns.boxplot(x=df['Monthly_Salary'])
plt.show()

# %%
sns.kdeplot(df['Experience_Years'], fill=True)
plt.show()

# %%
sns.lineplot(x='Experience_Years', y='Monthly_Salary', data=df)
plt.show()

# %%
sns.scatterplot(x='Experience_Years', y='Monthly_Salary', data=df)
plt.show()

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Employee_ID              100 non-null    int64
#  1   Age                      90 non-null     float64
#  2   Gender                   100 non-null    object
#  3   Department               90 non-null     object
#  4   Education                90 non-null     object
#  5   Experience_Years         100 non-null    int64
#  6   Monthly_Salary           90 non-null     float64
#  7   Performance_Rating       100 non-null    int64
#  8   City                     90 non-null     object
#  9   Attrition                100 non-null    object
#  10  Age_mean_imputed         100 non-null    float64
#  11  Department_mode_imputed  100 non-null    object
#  12  Education_mode_imputed   100 non-null    object
#  13  Salary_mean_imputed      100 non-null    float64
#  14  City_mode_imputed        100 non-null    object
# dtypes: float64(4), int64(3), object(8)
# memory usage: 11.8+ KB

# %%
label_encoder = LabelEncoder()
df['Gender_Encoded'] = label_encoder.fit_transform(df['Gender'])
one_hot_encoded = pd.get_dummies(
    df[['Department_mode_imputed',
        'Education_mode_imputed',
        'City_mode_imputed']],
    prefix=['Department', 'Education', 'City']
)
df = pd.concat([df, one_hot_encoded], axis=1)

# %%
df
# Out:
#     Employee_ID   Age  Gender Department  Education  Experience_Years  \
# 0          1001  59.0    Male         HR    Masters                18
# 1          1002  49.0  Female  Marketing  Bachelors                16
# 2          1003  35.0  Female         HR        NaN                19
# 3          1004  28.0  Female         HR        PhD                 9
# 4          1005  41.0    Male         IT  Bachelors                 5
# ..          ...   ...     ...        ...        ...               ...
# 95         1096  54.0  Female         HR    Masters                11
# 96         1097  53.0    Male  Marketing    Masters                13
# 97         1098  43.0    Male        NaN        PhD                 1
# 98         1099  44.0  Female  Marketing        PhD                18
# 99         1100  57.0  Female        NaN        NaN                17
#
#     Monthly_Salary  Performance_Rating        City Attrition  ...  \
# 0          52350.0                   5     Calicut        No  ...
# 1         118008.0                   2     Chennai       Yes  ...
# 2         119297.0                   1       Kochi       Yes  ...
# 3          50351.0                   2  Trivandrum       Yes  ...
# 4         113668.0                   3  Trivandrum       Yes  ...
# ..             ...                 ...         ...       ...  ...
# 95         48625.0                   5     Chennai       Yes  ...
# 96        107873.0                   5  Trivandrum       Yes  ...
# 97         97592.0                   3     Chennai        No  ...
# 98        102052.0                   5     Calicut       Yes  ...
# 99         69261.0                   2     Calicut        No  ...
#
#     Department_Marketing Department_Sales Education_Bachelors  \
# 0                  False            False               False
# 1                   True            False                True
# 2                  False            False               False
# 3                  False            False               False
# 4                  False            False                True
# ..                   ...              ...                 ...
# 95                 False            False               False
# 96                  True            False               False
# 97                 False            False               False
# 98                  True            False               False
# 99                 False            False               False
#
#     Education_Masters Education_PhD  City_Bangalore  City_Calicut  \
# 0                True         False           False          True
# 1               False         False           False         False
# 2                True         False           False         False
# 3               False          True           False         False
# 4               False         False           False         False
# ..                ...           ...             ...           ...
# 95               True         False           False         False
# 96               True         False           False         False
# 97              False          True           False         False
# 98              False          True           False          True
# 99               True         False           False          True
#
#     City_Chennai  City_Kochi  City_Trivandrum
# 0          False       False            False
# 1           True       False            False
# 2          False        True            False
# 3          False       False             True
# 4          False       False             True
# ..           ...         ...              ...
# 95          True       False            False
# 96         False       False             True
# 97          True       False            False
# 98         False       False            False
# 99         False       False            False
#
# [100 rows x 57 columns]

# %%
label_encoder = LabelEncoder()
df['Gender_Encoded'] = label_encoder.fit_transform(df['Gender'])
one_hot_encoded = pd.get_dummies(
    df[['Department_mode_imputed',
        'Education_mode_imputed',
        'City_mode_imputed']],
    prefix=['Department', 'Education', 'City']
)
df = pd.concat([df, one_hot_encoded], axis=1)

# %%
minmax_scaler = MinMaxScaler()

df[['Age_mean_imputed',
    'Experience_Years',
    'Salary_mean_imputed',
    'Performance_Rating']] = minmax_scaler.fit_transform(
        df[['Age_mean_imputed','Experience_Years','Salary_mean_imputed','Performance_Rating']])

# %%
standard_scaler = StandardScaler()

df[['Age_mean_imputed',
    'Experience_Years',
    'Salary_mean_imputed',
    'Performance_Rating']] = standard_scaler.fit_transform(
    df[['Age_mean_imputed','Experience_Years','Salary_mean_imputed','Performance_Rating']])

# %%
df[['Age_mean_imputed','Experience_Years','Salary_mean_imputed','Performance_Rating']].head()
# Out:
#    Age_mean_imputed  Experience_Years  Salary_mean_imputed  Performance_Rating
# 0          1.841242          1.398095            -0.859586            1.205142
# 1          0.878921          1.074462             1.619930           -0.837471
# 2         -0.468330          1.559911             1.668607           -1.518342
# 3         -1.141955         -0.058254            -0.935077           -0.837471
# 4          0.109063         -0.705520             1.456033           -0.156600
